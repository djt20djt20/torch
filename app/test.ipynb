# %%
import sys
sys.path.insert(0, "../app")

from model import load_model, predict

# Load the saved artifact
model = load_model()

# Test with a real-looking record (all raw fields, no loss_ratio / is_loss_making)
record = {
    "risk_type": "property",
    "territory": "UK",
    "industry": "healthcare",
    "limit": 665000,
    "premium": 15200,
    "broker": "Nexus Broking",
    "prior_claims": 1.0,
    "years_trading": 28.0,
}

result = predict(model, record)
print("Prediction:  ", result["is_loss_making_prediction"])
print("Confidence:  ", result["confidence"])
print("Top features:", result["top_features"])
print("SHAP values: ", result["shap_values"])
print("Warnings:    ", result["warnings"])
# Out:
# Prediction:   False
# Confidence:   0.3448
# Top features: ['risk_type', 'industry', 'broker', 'territory', 'premium', 'prior_claims', 'prior_claim_rate', 'limit', 'premium_rate', 'years_trading']
# SHAP values:  {'risk_type': -1.055487, 'industry': 0.586953, 'broker': -0.342563, 'territory': 0.187606, 'premium': 0.126877, 'prior_claims': -0.06245, 'prior_claim_rate': -0.057495, 'limit': -0.054027, 'premium_rate': -0.038782, 'years_trading': -0.032275}
# Warnings:     []
# c:\Users\djt20\CascadeProjects\torch-techtest\.venv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.2 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\djt20\CascadeProjects\torch-techtest\.venv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.7.2 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\djt20\CascadeProjects\torch-techtest\.venv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.7.2 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\djt20\CascadeProjects\torch-techtest\.venv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator _SigmoidCalibration from version 1.7.2 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\djt20\CascadeProjects\torch-techtest\.venv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator CalibratedClassifierCV from version 1.7.2 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
import sys
sys.path.insert(0, "c:/Users/djt20/CascadeProjects/torch-techtest")

import json
from app.vectorstore import init as init_vectorstore
from app.agent import run_agent

# Initialise the vectorstore (normally done by FastAPI lifespan)
init_vectorstore()

record = json.loads(open("c:/Users/djt20/CascadeProjects/torch-techtest/data/new_record.json").read())
result = run_agent(record)

print("Tools used:", result["tools_used"])
print()
print(result["recommendation"])
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# c:\Users\djt20\CascadeProjects\torch-techtest\.venv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.2 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\djt20\CascadeProjects\torch-techtest\.venv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.7.2 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\djt20\CascadeProjects\torch-techtest\.venv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.7.2 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\djt20\CascadeProjects\torch-techtest\.venv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator _SigmoidCalibration from version 1.7.2 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\djt20\CascadeProjects\torch-techtest\.venv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator CalibratedClassifierCV from version 1.7.2 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Tools used: ['predict_loss', 'retrieve_similar_records']
#
# Good — all three historical matches have cosine distances well below 0.4, making them meaningfully comparable. Here is my assessment:
#
# ---
#
# ## Underwriting Recommendation — Record NEW_0001
#
# ### Prediction: **Likely Loss-Making | Moderate Confidence (~66%)**
#
# The model predicts this policy will be loss-making, with moderate confidence. While this is not a high-certainty call, the weight of evidence leans toward elevated risk and the record warrants careful scrutiny.
#
# ---
#
# ### Key Risk Drivers
#
# 1. **Cyber cover is the dominant risk signal.** The single biggest factor pushing toward a loss prediction is simply that this is a cyber policy. Across the book, cyber risk type is strongly associated with loss outcomes — and that pattern is holding here.
#
# 2. **The insured is a young business (4 years trading).** Companies with limited operating history tend to have less mature IT infrastructure, security governance, and incident-response capability. Four years of trading is notably young compared to the historical comparables (see below), all of which involve businesses with 40+ years of trading history. This immaturity is contributing meaningfully to the loss signal.
#
# 3. **Prior claim rate adds further concern.** Although the raw count of one prior claim is modest, the *rate* of claims relative to years in business is elevated (one claim in four years). This is a meaningful red flag for a young company and is flagging as a negative driver in the model.
#
# **Partial offsets:** The EU territory and the transport industry are both providing slight downward pressure on the loss probability — EU regulatory environments may impose stronger cyber hygiene standards, and the transport sector profile is somewhat less adverse than, say, healthcare or financial services. The limit (€3.44m) is also relatively modest, which reduces severity exposure.
#
# ---
#
# ### Historical Comparables
#
# Three closely matched historical records were retrieved (all with strong similarity scores):
#
# - **REC_0247** — EU cyber/transport account with 2 prior claims, £8.3m limit, submitted by Brockton & Gray. Relevant as a higher-limit, higher-claim-count comparator in the same risk/territory/industry segment.
# - **REC_0377** — EU cyber/transport account with 1 prior claim, £10.1m limit, submitted by **Meridian Re** (the same broker as this submission). Directly comparable on risk type, territory, industry, broker, and prior claim count.
# - **REC_0108** — EU cyber/transport account with *no* prior claims, £3.0m limit — the closest structural match to this account by limit size, and notably clean on claims history.
#
# The key distinction between this record and the comparables is **years of trading**: all three historical accounts are well-established businesses (40+ years), whereas this insured has only 4 years of history. This is a significant differentiator and likely explains a meaningful portion of the elevated loss probability.
#
# ---
#
# ### Data Quality
#
# No data quality warnings or out-of-distribution flags were raised by the model. The inputs appear clean and complete.
#
# ---
#
# ### Recommendation: **Refer for Senior Review**
#
# Do not approve at standard terms. The moderate confidence level (66%) means this is not a clear-cut decline, but the combination of **cyber risk type**, **very short trading history**, and **an existing prior claim** creates a risk profile that sits above appetite for a straightforward approval. The premium rate also appears thin relative to the limit (roughly 0.78%), especially given the elevated loss indicators.
#
# A senior underwriter should consider:
# - Requesting evidence of the insured's cybersecurity posture (e.g., penetration testing, ISO 27001 certification, incident response plan).
# - Obtaining full details of the prior claim before binding.
# - Assessing whether a **rate adjustment or sub-limit** on first-party losses is appropriate given the business's youth and claims history.
